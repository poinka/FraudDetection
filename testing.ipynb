# %%
# Basic data manipulation
import pandas as pd
import numpy as np
import random

# Visualization
import matplotlib.pyplot as plt

# Sklearn imports
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.svm import SVC, LinearSVC
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.utils.class_weight import compute_class_weight
from sklearn.impute import SimpleImputer

# Classifiers
from catboost import CatBoostClassifier

# Additional encoders
import category_encoders as ce

# Stats
import scipy.stats as stats

# Dimensionality reduction
from sklearn.decomposition import (
    PCA,
    KernelPCA, 
    FastICA,
    TruncatedSVD
)

# %% [markdown]
# ### Download all Data

# %%
test = pd.read_csv("data/test_for_model_eval.csv")
transaction_ids = test["TransactionID"].astype(int)
test = test.drop(columns=["TransactionID"])

# %%
X_train_scaled = pd.read_csv("data/preprocessed_train.csv")
X_test_scaled = pd.read_csv("data/preprocessed_test.csv")
y_train = pd.read_csv("data/y_train.csv")
y_test = pd.read_csv("data/y_test.csv")

# %% [markdown]
# ### Get weights

# %%
# Convert y_train to numpy array (since it's read as DataFrame)
y_train_array = y_train['isFraud'].values

# Get unique classes and compute weights
unique_classes = np.unique(y_train_array)
class_weights = compute_class_weight(
    class_weight="balanced",
    classes=unique_classes,
    y=y_train_array
)

# Create dictionary of class weights
class_weights_dict = dict(zip(unique_classes, class_weights))
class_weights_dict = {int(k): float(v) for k, v in class_weights_dict.items()}

# %% [markdown]
# ### 1. All Features

# %%
y_train_flat = y_train.values.ravel()
y_test_flat = y_test.values.ravel()

model_cat = CatBoostClassifier(
    iterations=500,
    learning_rate=0.1,
    depth=6,
    class_weights=class_weights_dict,
    random_seed=42,
    verbose=100
)
model_cat.fit(X_train_scaled, y_train_flat)
y_pred_cat = model_cat.predict(X_test_scaled)

print("CatBoost Training Accuracy:", accuracy_score(y_test_flat, y_pred_cat))
# Out:
# 0:	learn: 0.6495989	total: 148ms	remaining: 1m 13s
# 100:	learn: 0.3757994	total: 14.5s	remaining: 57.5s
# 200:	learn: 0.3300922	total: 28.7s	remaining: 42.7s
# 300:	learn: 0.2994735	total: 43.1s	remaining: 28.5s
# 400:	learn: 0.2770163	total: 59.4s	remaining: 14.7s
# 499:	learn: 0.2581595	total: 1m 15s	remaining: 0us
# CatBoost Training Accuracy: 0.916229213939784

# %%
y_pred_test = model_cat.predict_proba(test)
fraud_probs = y_pred_test[:, 1]

# %%
submission_df = pd.DataFrame({
    'TransactionID': transaction_ids,
    'isFraud': fraud_probs
})

# %%
submission_df.to_csv('submissions/all_features.csv', index=False)

# %% [markdown]
# #### On test set: 0.889037  &   0.922709

# %% [markdown]
# ### 2. PCA

# %%
X_train_scaled = pd.read_csv("data/preprocessed_train.csv")
X_test_scaled = pd.read_csv("data/preprocessed_test.csv")
y_train = pd.read_csv("data/y_train.csv")
y_test = pd.read_csv("data/y_test.csv")


test = pd.read_csv("data/test_for_model_eval.csv")
transaction_ids = test["TransactionID"].astype(int)
test = test.drop(columns=["TransactionID"])


pca = PCA(n_components=30)
X_train_scaled = pca.fit_transform(X_train_scaled)
X_test_scaled = pca.transform(X_test_scaled)


test = pca.transform(test)


y_train_flat = y_train.values.ravel()
y_test_flat = y_test.values.ravel()

model_cat = CatBoostClassifier(
    iterations=500,
    learning_rate=0.1,
    depth=6,
    class_weights=class_weights_dict,
    random_seed=42,
    verbose=100
)
model_cat.fit(X_train_scaled, y_train_flat)
y_pred_cat = model_cat.predict(X_test_scaled)

print("CatBoost Training Accuracy:", accuracy_score(y_test_flat, y_pred_cat))


y_pred_test = model_cat.predict_proba(test)
fraud_probs = y_pred_test[:, 1]


submission_df = pd.DataFrame({
    'TransactionID': transaction_ids,
    'isFraud': fraud_probs
})

submission_df.to_csv('submissions/pca.csv', index=False)

# %% [markdown]
# #### On test set: 0.821966  &  0.872178

# %% [markdown]
# ### 3. ICA

# %%
X_train_scaled = pd.read_csv("data/preprocessed_train.csv")
X_test_scaled = pd.read_csv("data/preprocessed_test.csv")
y_train = pd.read_csv("data/y_train.csv")
y_test = pd.read_csv("data/y_test.csv")


test = pd.read_csv("data/test_for_model_eval.csv")
transaction_ids = test["TransactionID"].astype(int)
test = test.drop(columns=["TransactionID"])


ica = FastICA(n_components=30, random_state=42)
X_train_scaled = ica.fit_transform(X_train_scaled)
X_test_scaled = ica.transform(X_test_scaled)


test = ica.transform(test)


y_train_flat = y_train.values.ravel()
y_test_flat = y_test.values.ravel()

model_cat = CatBoostClassifier(
    iterations=500,
    learning_rate=0.1,
    depth=6,
    class_weights=class_weights_dict,
    random_seed=42,
    verbose=100
)
model_cat.fit(X_train_scaled, y_train_flat)
y_pred_cat = model_cat.predict(X_test_scaled)

print("CatBoost Training Accuracy:", accuracy_score(y_test_flat, y_pred_cat))


y_pred_test = model_cat.predict_proba(test)
fraud_probs = y_pred_test[:, 1]


submission_df = pd.DataFrame({
    'TransactionID': transaction_ids,
    'isFraud': fraud_probs
})

submission_df.to_csv('submissions/ica.csv', index=False)
# Out:
# 0:	learn: 0.6618624	total: 30.9ms	remaining: 15.4s
# 100:	learn: 0.4496866	total: 2.35s	remaining: 9.29s
# 200:	learn: 0.4186339	total: 4.91s	remaining: 7.3s
# 300:	learn: 0.3950734	total: 7.32s	remaining: 4.84s
# 400:	learn: 0.3757994	total: 9.59s	remaining: 2.37s
# 499:	learn: 0.3596274	total: 11.7s	remaining: 0us
# CatBoost Training Accuracy: 0.8600179496731805

# %% [markdown]
# #### On test set: 0.818411  &  0.875235

# %% [markdown]
# ### 4. SVD

# %%
X_train_scaled = pd.read_csv("data/preprocessed_train.csv")
X_test_scaled = pd.read_csv("data/preprocessed_test.csv")
y_train = pd.read_csv("data/y_train.csv")
y_test = pd.read_csv("data/y_test.csv")


test = pd.read_csv("data/test_for_model_eval.csv")
transaction_ids = test["TransactionID"].astype(int)
test = test.drop(columns=["TransactionID"])


svd = TruncatedSVD(n_components=30, random_state=42)
X_train_scaled = svd.fit_transform(X_train_scaled)
X_test_scaled = svd.transform(X_test_scaled)


test = ica.transform(test)


y_train_flat = y_train.values.ravel()
y_test_flat = y_test.values.ravel()

model_cat = CatBoostClassifier(
    iterations=500,
    learning_rate=0.1,
    depth=6,
    class_weights=class_weights_dict,
    random_seed=42,
    verbose=100
)
model_cat.fit(X_train_scaled, y_train_flat)
y_pred_cat = model_cat.predict(X_test_scaled)

print("CatBoost Training Accuracy:", accuracy_score(y_test_flat, y_pred_cat))


y_pred_test = model_cat.predict_proba(test)
fraud_probs = y_pred_test[:, 1]


submission_df = pd.DataFrame({
    'TransactionID': transaction_ids,
    'isFraud': fraud_probs
})

submission_df.to_csv('submissions/svd.csv', index=False)
# Out:
# 0:	learn: 0.6564137	total: 35.6ms	remaining: 17.8s
# 100:	learn: 0.4548501	total: 2.06s	remaining: 8.14s
# 200:	learn: 0.4276080	total: 4.39s	remaining: 6.54s
# 300:	learn: 0.4069344	total: 6.88s	remaining: 4.54s
# 400:	learn: 0.3904750	total: 9.32s	remaining: 2.3s
# 499:	learn: 0.3764382	total: 11.7s	remaining: 0us
# CatBoost Training Accuracy: 0.8502387645206082

# %% [markdown]
# #### On test set: 0.446137  &  0.452396

# %% [markdown]
# ### 5. GA

# %%
X_train_scaled = pd.read_csv("data/preprocessed_train.csv")
X_test_scaled = pd.read_csv("data/preprocessed_test.csv")
y_train = pd.read_csv("data/y_train.csv")
y_test = pd.read_csv("data/y_test.csv")


test = pd.read_csv("data/test_for_model_eval.csv")
transaction_ids = test["TransactionID"].astype(int)
test = test.drop(columns=["TransactionID"])

# %%
def run_genetic_algorithm(X_data, y_data, population_size=30, n_generations=20, subset_size=30):
    n_features = X_data.shape[1]
    
    # Initialize population - each individual is a sorted list of feature indices
    population = []
    for _ in range(population_size):
        subset = random.sample(range(n_features), subset_size)
        subset.sort()
        population.append(subset)
    
    def fitness(individual):
        X_subset = X_data.iloc[:, individual]
        
        # Manual train/test split instead of cross-validation
        X_train_subset, X_val_subset, y_train_subset, y_val_subset = train_test_split(
            X_subset, y_data, test_size=0.2, random_state=42, stratify=y_data
        )
        
        try:
            model = CatBoostClassifier(
                iterations=100,  # Reduce from 500 to speed up GA
                learning_rate=0.1,
                depth=6,
                class_weights=class_weights_dict,
                random_seed=42,
                verbose=0        # Turn off verbosity completely            
            )
            
            # Use a simple fit instead of cross_val_score
            model.fit(X_train_subset, y_train_subset, 
                     eval_set=(X_val_subset, y_val_subset),
                     early_stopping_rounds=20,
                     verbose=False)
            
            # Get validation accuracy
            accuracy = accuracy_score(y_val_subset, model.predict(X_val_subset))
            print(f"Feature subset evaluated: accuracy = {accuracy:.4f}")
            return accuracy
            
        except Exception as e:
            print(f"Error in fitness evaluation: {e}")
            return 0.0  # Return worst fitness on error
    
    # Creates a child by merging features from both parents and selecting a random subset
    def crossover(p1, p2, subset_size):
        combined = list(set(p1) | set(p2))  # Union of features
        if len(combined) > subset_size:
            child = sorted(random.sample(combined, subset_size))  # Ensure correct size
        else:
            child = sorted(combined)  # Keep all if below subset_size
        return child

    # Mutation replaces a random index in child if random.threshold is met
    def mutation(individual, n_features, subset_size):
        if random.random() < 0.1:  # 10% chance of mutation
            i = random.randrange(subset_size)
            available_features = set(range(n_features)) - set(individual)  # Exclude existing features
            if available_features:  
                new_feature = random.choice(list(available_features))
                individual[i] = new_feature
                individual.sort()
        return individual


    for i in range(n_generations):
        print(f"\nGeneration {i+1}/{n_generations}")
        # Evaluate fitness of population
        print("Evaluating fitness for each individual:")
        scored_population = []
        for idx, ind in enumerate(population):
            fitness_score = fitness(ind)
            scored_population.append((fitness_score, ind))
            print(f"Individual {idx+1}/{len(population)}: Fitness = {fitness_score:.4f}")
        
        scored_population.sort(key=lambda x: x[0], reverse=True)
        print(f"\nBest fitness in generation {i+1}: {scored_population[0][0]:.4f}")
        
        # Selection: truncation selection (pick top half as survivors)
        survivors = scored_population[: population_size // 2]
        
        # Then randomly select two parents (p1 & p2) from survivors for crossover + mutation
        print("Creating new population...")
        new_pop = [s[1] for s in survivors]
        while len(new_pop) < population_size:
            print("Generating new individual...")
            
            p1 = random.choice(survivors)[1]
            p2 = random.choice(survivors)[1]
            child = crossover(p1, p2, subset_size)
            child = mutation(child, n_features, subset_size)
            
            child = list(set(child))  # remove duplicates if any
            while len(child) < subset_size:  # if duplicates reduced size
                child.append(random.randrange(n_features))
            child.sort()
            new_pop.append(child)
            
            print("New individual created! Happy birthday!")
        population = new_pop
        print("Current best:", max([(fitness(ind), ind) for ind in population], key=lambda x: x[0])[1])
    
    best = max([(fitness(ind), ind) for ind in population], key=lambda x: x[0])[1]
    return best

best_features = run_genetic_algorithm(X_train_scaled, y_train)
X_train_ga = X_train_scaled.iloc[:, best_features]
X_test_ga = X_test_scaled.iloc[:, best_features]
model = CatBoostClassifier(
            iterations=500,
            learning_rate=0.1,
            depth=6,
            class_weights=class_weights_dict,
            random_seed=42,
            verbose=100
        )
model.fit(X_train_ga, y_train)
y_pred = model.predict(X_test_ga)
print("Model accuracy with selected features:", accuracy_score(y_test, y_pred))
# Out:
# Generation 1/20
# Evaluating fitness for each individual:
# Feature subset evaluated: accuracy = 0.8083
# Individual 1/30: Fitness = 0.8083
# Feature subset evaluated: accuracy = 0.8066
# Individual 2/30: Fitness = 0.8066
# Feature subset evaluated: accuracy = 0.8113
# Individual 3/30: Fitness = 0.8113
# Feature subset evaluated: accuracy = 0.8134
# Individual 4/30: Fitness = 0.8134
# Feature subset evaluated: accuracy = 0.8003
# Individual 5/30: Fitness = 0.8003
# Feature subset evaluated: accuracy = 0.8111
# Individual 6/30: Fitness = 0.8111
# Feature subset evaluated: accuracy = 0.7971
# Individual 7/30: Fitness = 0.7971
# Feature subset evaluated: accuracy = 0.7904
# Individual 8/30: Fitness = 0.7904
# Feature subset evaluated: accuracy = 0.8292
# Individual 9/30: Fitness = 0.8292
# Feature subset evaluated: accuracy = 0.7861
# Individual 10/30: Fitness = 0.7861
# Feature subset evaluated: accuracy = 0.7827
# Individual 11/30: Fitness = 0.7827
# Feature subset evaluated: accuracy = 0.8191
# Individual 12/30: Fitness = 0.8191
# Feature subset evaluated: accuracy = 0.8290
# Individual 13/30: Fitness = 0.8290
# Feature subset evaluated: accuracy = 0.8490
# Individual 14/30: Fitness = 0.8490
# Feature subset evaluated: accuracy = 0.8053
# Individual 15/30: Fitness = 0.8053
# Feature subset evaluated: accuracy = 0.8174
# Individual 16/30: Fitness = 0.8174
# Feature subset evaluated: accuracy = 0.8173
# Individual 17/30: Fitness = 0.8173
# Feature subset evaluated: accuracy = 0.8054
# Individual 18/30: Fitness = 0.8054
# Feature subset evaluated: accuracy = 0.8377
# Individual 19/30: Fitness = 0.8377
# Feature subset evaluated: accuracy = 0.7896
# Individual 20/30: Fitness = 0.7896
# Feature subset evaluated: accuracy = 0.8179
# Individual 21/30: Fitness = 0.8179
# Feature subset evaluated: accuracy = 0.8047
# Individual 22/30: Fitness = 0.8047
# Feature subset evaluated: accuracy = 0.8334
# Individual 23/30: Fitness = 0.8334
# Feature subset evaluated: accuracy = 0.8279
# Individual 24/30: Fitness = 0.8279
# Feature subset evaluated: accuracy = 0.7859
# Individual 25/30: Fitness = 0.7859
# Feature subset evaluated: accuracy = 0.8374
# Individual 26/30: Fitness = 0.8374
# Feature subset evaluated: accuracy = 0.8211
# Individual 27/30: Fitness = 0.8211
# Feature subset evaluated: accuracy = 0.8279
# Individual 28/30: Fitness = 0.8279
# Feature subset evaluated: accuracy = 0.8017
# Individual 29/30: Fitness = 0.8017
# Feature subset evaluated: accuracy = 0.8300
# Individual 30/30: Fitness = 0.8300
#
# Best fitness in generation 1: 0.8490
# Creating new population...
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Feature subset evaluated: accuracy = 0.8490
# Feature subset evaluated: accuracy = 0.8377
# Feature subset evaluated: accuracy = 0.8374
# Feature subset evaluated: accuracy = 0.8334
# Feature subset evaluated: accuracy = 0.8300
# Feature subset evaluated: accuracy = 0.8292
# Feature subset evaluated: accuracy = 0.8290
# Feature subset evaluated: accuracy = 0.8279
# Feature subset evaluated: accuracy = 0.8279
# Feature subset evaluated: accuracy = 0.8211
# Feature subset evaluated: accuracy = 0.8191
# Feature subset evaluated: accuracy = 0.8179
# Feature subset evaluated: accuracy = 0.8174
# Feature subset evaluated: accuracy = 0.8173
# Feature subset evaluated: accuracy = 0.8134
# Feature subset evaluated: accuracy = 0.7982
# Feature subset evaluated: accuracy = 0.8461
# Feature subset evaluated: accuracy = 0.8159
# Feature subset evaluated: accuracy = 0.8220
# Feature subset evaluated: accuracy = 0.8256
# Feature subset evaluated: accuracy = 0.8377
# Feature subset evaluated: accuracy = 0.8223
# Feature subset evaluated: accuracy = 0.8141
# Feature subset evaluated: accuracy = 0.8246
# Feature subset evaluated: accuracy = 0.8389
# Feature subset evaluated: accuracy = 0.8217
# Feature subset evaluated: accuracy = 0.8150
# Feature subset evaluated: accuracy = 0.8096
# Feature subset evaluated: accuracy = 0.8134
# Feature subset evaluated: accuracy = 0.8262
# Current best: [12, 16, 63, 85, 94, 96, 109, 115, 123, 139, 143, 154, 180, 193, 199, 204, 210, 214, 243, 249, 318, 331, 342, 355, 373, 403, 414, 416, 417, 420]
#
# Generation 2/20
# Evaluating fitness for each individual:
# Feature subset evaluated: accuracy = 0.8490
# Individual 1/30: Fitness = 0.8490
# Feature subset evaluated: accuracy = 0.8377
# Individual 2/30: Fitness = 0.8377
# Feature subset evaluated: accuracy = 0.8374
# Individual 3/30: Fitness = 0.8374
# Feature subset evaluated: accuracy = 0.8334
# Individual 4/30: Fitness = 0.8334
# Feature subset evaluated: accuracy = 0.8300
# Individual 5/30: Fitness = 0.8300
# Feature subset evaluated: accuracy = 0.8292
# Individual 6/30: Fitness = 0.8292
# Feature subset evaluated: accuracy = 0.8290
# Individual 7/30: Fitness = 0.8290
# Feature subset evaluated: accuracy = 0.8279
# Individual 8/30: Fitness = 0.8279
# Feature subset evaluated: accuracy = 0.8279
# Individual 9/30: Fitness = 0.8279
# Feature subset evaluated: accuracy = 0.8211
# Individual 10/30: Fitness = 0.8211
# Feature subset evaluated: accuracy = 0.8191
# Individual 11/30: Fitness = 0.8191
# Feature subset evaluated: accuracy = 0.8179
# Individual 12/30: Fitness = 0.8179
# Feature subset evaluated: accuracy = 0.8174
# Individual 13/30: Fitness = 0.8174
# Feature subset evaluated: accuracy = 0.8173
# Individual 14/30: Fitness = 0.8173
# Feature subset evaluated: accuracy = 0.8134
# Individual 15/30: Fitness = 0.8134
# Feature subset evaluated: accuracy = 0.7982
# Individual 16/30: Fitness = 0.7982
# Feature subset evaluated: accuracy = 0.8461
# Individual 17/30: Fitness = 0.8461
# Feature subset evaluated: accuracy = 0.8159
# Individual 18/30: Fitness = 0.8159
# Feature subset evaluated: accuracy = 0.8220
# Individual 19/30: Fitness = 0.8220
# Feature subset evaluated: accuracy = 0.8256
# Individual 20/30: Fitness = 0.8256
# Feature subset evaluated: accuracy = 0.8377
# Individual 21/30: Fitness = 0.8377
# Feature subset evaluated: accuracy = 0.8223
# Individual 22/30: Fitness = 0.8223
# Feature subset evaluated: accuracy = 0.8141
# Individual 23/30: Fitness = 0.8141
# Feature subset evaluated: accuracy = 0.8246
# Individual 24/30: Fitness = 0.8246
# Feature subset evaluated: accuracy = 0.8389
# Individual 25/30: Fitness = 0.8389
# Feature subset evaluated: accuracy = 0.8217
# Individual 26/30: Fitness = 0.8217
# Feature subset evaluated: accuracy = 0.8150
# Individual 27/30: Fitness = 0.8150
# Feature subset evaluated: accuracy = 0.8096
# Individual 28/30: Fitness = 0.8096
# Feature subset evaluated: accuracy = 0.8134
# Individual 29/30: Fitness = 0.8134
# Feature subset evaluated: accuracy = 0.8262
# Individual 30/30: Fitness = 0.8262
#
# Best fitness in generation 2: 0.8490
# Creating new population...
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Feature subset evaluated: accuracy = 0.8490
# Feature subset evaluated: accuracy = 0.8461
# Feature subset evaluated: accuracy = 0.8389
# Feature subset evaluated: accuracy = 0.8377
# Feature subset evaluated: accuracy = 0.8377
# Feature subset evaluated: accuracy = 0.8374
# Feature subset evaluated: accuracy = 0.8334
# Feature subset evaluated: accuracy = 0.8300
# Feature subset evaluated: accuracy = 0.8292
# Feature subset evaluated: accuracy = 0.8290
# Feature subset evaluated: accuracy = 0.8279
# Feature subset evaluated: accuracy = 0.8279
# Feature subset evaluated: accuracy = 0.8262
# Feature subset evaluated: accuracy = 0.8256
# Feature subset evaluated: accuracy = 0.8246
# Feature subset evaluated: accuracy = 0.8240
# Feature subset evaluated: accuracy = 0.8389
# Feature subset evaluated: accuracy = 0.8245
# Feature subset evaluated: accuracy = 0.8429
# Feature subset evaluated: accuracy = 0.8424
# Feature subset evaluated: accuracy = 0.8407
# Feature subset evaluated: accuracy = 0.8189
# Feature subset evaluated: accuracy = 0.8400
# Feature subset evaluated: accuracy = 0.8231
# Feature subset evaluated: accuracy = 0.8296
# Feature subset evaluated: accuracy = 0.8392
# Feature subset evaluated: accuracy = 0.7907
# Feature subset evaluated: accuracy = 0.8195
# Feature subset evaluated: accuracy = 0.8514
# Feature subset evaluated: accuracy = 0.7928
# Current best: [20, 65, 72, 78, 80, 84, 86, 99, 106, 109, 110, 130, 148, 177, 179, 190, 192, 212, 237, 259, 261, 274, 286, 297, 308, 359, 362, 380, 393, 419]
#
# Generation 3/20
# Evaluating fitness for each individual:
# Feature subset evaluated: accuracy = 0.8490
# Individual 1/30: Fitness = 0.8490
# Feature subset evaluated: accuracy = 0.8461
# Individual 2/30: Fitness = 0.8461
# Feature subset evaluated: accuracy = 0.8389
# Individual 3/30: Fitness = 0.8389
# Feature subset evaluated: accuracy = 0.8377
# Individual 4/30: Fitness = 0.8377
# Feature subset evaluated: accuracy = 0.8377
# Individual 5/30: Fitness = 0.8377
# Feature subset evaluated: accuracy = 0.8374
# Individual 6/30: Fitness = 0.8374
# Feature subset evaluated: accuracy = 0.8334
# Individual 7/30: Fitness = 0.8334
# Feature subset evaluated: accuracy = 0.8300
# Individual 8/30: Fitness = 0.8300
# Feature subset evaluated: accuracy = 0.8292
# Individual 9/30: Fitness = 0.8292
# Feature subset evaluated: accuracy = 0.8290
# Individual 10/30: Fitness = 0.8290
# Feature subset evaluated: accuracy = 0.8279
# Individual 11/30: Fitness = 0.8279
# Feature subset evaluated: accuracy = 0.8279
# Individual 12/30: Fitness = 0.8279
# Feature subset evaluated: accuracy = 0.8262
# Individual 13/30: Fitness = 0.8262
# Feature subset evaluated: accuracy = 0.8256
# Individual 14/30: Fitness = 0.8256
# Feature subset evaluated: accuracy = 0.8246
# Individual 15/30: Fitness = 0.8246
# Feature subset evaluated: accuracy = 0.8240
# Individual 16/30: Fitness = 0.8240
# Feature subset evaluated: accuracy = 0.8389
# Individual 17/30: Fitness = 0.8389
# Feature subset evaluated: accuracy = 0.8245
# Individual 18/30: Fitness = 0.8245
# Feature subset evaluated: accuracy = 0.8429
# Individual 19/30: Fitness = 0.8429
# Feature subset evaluated: accuracy = 0.8424
# Individual 20/30: Fitness = 0.8424
# Feature subset evaluated: accuracy = 0.8407
# Individual 21/30: Fitness = 0.8407
# Feature subset evaluated: accuracy = 0.8189
# Individual 22/30: Fitness = 0.8189
# Feature subset evaluated: accuracy = 0.8400
# Individual 23/30: Fitness = 0.8400
# Feature subset evaluated: accuracy = 0.8231
# Individual 24/30: Fitness = 0.8231
# Feature subset evaluated: accuracy = 0.8296
# Individual 25/30: Fitness = 0.8296
# Feature subset evaluated: accuracy = 0.8392
# Individual 26/30: Fitness = 0.8392
# Feature subset evaluated: accuracy = 0.7907
# Individual 27/30: Fitness = 0.7907
# Feature subset evaluated: accuracy = 0.8195
# Individual 28/30: Fitness = 0.8195
# Feature subset evaluated: accuracy = 0.8514
# Individual 29/30: Fitness = 0.8514
# Feature subset evaluated: accuracy = 0.7928
# Individual 30/30: Fitness = 0.7928
#
# Best fitness in generation 3: 0.8514
# Creating new population...
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Feature subset evaluated: accuracy = 0.8514
# Feature subset evaluated: accuracy = 0.8490
# Feature subset evaluated: accuracy = 0.8461
# Feature subset evaluated: accuracy = 0.8429
# Feature subset evaluated: accuracy = 0.8424
# Feature subset evaluated: accuracy = 0.8407
# Feature subset evaluated: accuracy = 0.8400
# Feature subset evaluated: accuracy = 0.8392
# Feature subset evaluated: accuracy = 0.8389
# Feature subset evaluated: accuracy = 0.8389
# Feature subset evaluated: accuracy = 0.8377
# Feature subset evaluated: accuracy = 0.8377
# Feature subset evaluated: accuracy = 0.8374
# Feature subset evaluated: accuracy = 0.8334
# Feature subset evaluated: accuracy = 0.8300
# Feature subset evaluated: accuracy = 0.8259
# Feature subset evaluated: accuracy = 0.8473
# Feature subset evaluated: accuracy = 0.8194
# Feature subset evaluated: accuracy = 0.8393
# Feature subset evaluated: accuracy = 0.8133
# Feature subset evaluated: accuracy = 0.8205
# Feature subset evaluated: accuracy = 0.8193
# Feature subset evaluated: accuracy = 0.8399
# Feature subset evaluated: accuracy = 0.8239
# Feature subset evaluated: accuracy = 0.8154
# Feature subset evaluated: accuracy = 0.8212
# Feature subset evaluated: accuracy = 0.8497
# Feature subset evaluated: accuracy = 0.8248
# Feature subset evaluated: accuracy = 0.8200
# Feature subset evaluated: accuracy = 0.8222
# Current best: [20, 65, 72, 78, 80, 84, 86, 99, 106, 109, 110, 130, 148, 177, 179, 190, 192, 212, 237, 259, 261, 274, 286, 297, 308, 359, 362, 380, 393, 419]
#
# Generation 4/20
# Evaluating fitness for each individual:
# Feature subset evaluated: accuracy = 0.8514
# Individual 1/30: Fitness = 0.8514
# Feature subset evaluated: accuracy = 0.8490
# Individual 2/30: Fitness = 0.8490
# Feature subset evaluated: accuracy = 0.8461
# Individual 3/30: Fitness = 0.8461
# Feature subset evaluated: accuracy = 0.8429
# Individual 4/30: Fitness = 0.8429
# Feature subset evaluated: accuracy = 0.8424
# Individual 5/30: Fitness = 0.8424
# Feature subset evaluated: accuracy = 0.8407
# Individual 6/30: Fitness = 0.8407
# Feature subset evaluated: accuracy = 0.8400
# Individual 7/30: Fitness = 0.8400
# Feature subset evaluated: accuracy = 0.8392
# Individual 8/30: Fitness = 0.8392
# Feature subset evaluated: accuracy = 0.8389
# Individual 9/30: Fitness = 0.8389
# Feature subset evaluated: accuracy = 0.8389
# Individual 10/30: Fitness = 0.8389
# Feature subset evaluated: accuracy = 0.8377
# Individual 11/30: Fitness = 0.8377
# Feature subset evaluated: accuracy = 0.8377
# Individual 12/30: Fitness = 0.8377
# Feature subset evaluated: accuracy = 0.8374
# Individual 13/30: Fitness = 0.8374
# Feature subset evaluated: accuracy = 0.8334
# Individual 14/30: Fitness = 0.8334
# Feature subset evaluated: accuracy = 0.8300
# Individual 15/30: Fitness = 0.8300
# Feature subset evaluated: accuracy = 0.8259
# Individual 16/30: Fitness = 0.8259
# Feature subset evaluated: accuracy = 0.8473
# Individual 17/30: Fitness = 0.8473
# Feature subset evaluated: accuracy = 0.8194
# Individual 18/30: Fitness = 0.8194
# Feature subset evaluated: accuracy = 0.8393
# Individual 19/30: Fitness = 0.8393
# Feature subset evaluated: accuracy = 0.8133
# Individual 20/30: Fitness = 0.8133
# Feature subset evaluated: accuracy = 0.8205
# Individual 21/30: Fitness = 0.8205
# Feature subset evaluated: accuracy = 0.8193
# Individual 22/30: Fitness = 0.8193
# Feature subset evaluated: accuracy = 0.8399
# Individual 23/30: Fitness = 0.8399
# Feature subset evaluated: accuracy = 0.8239
# Individual 24/30: Fitness = 0.8239
# Feature subset evaluated: accuracy = 0.8154
# Individual 25/30: Fitness = 0.8154
# Feature subset evaluated: accuracy = 0.8212
# Individual 26/30: Fitness = 0.8212
# Feature subset evaluated: accuracy = 0.8497
# Individual 27/30: Fitness = 0.8497
# Feature subset evaluated: accuracy = 0.8248
# Individual 28/30: Fitness = 0.8248
# Feature subset evaluated: accuracy = 0.8200
# Individual 29/30: Fitness = 0.8200
# Feature subset evaluated: accuracy = 0.8222
# Individual 30/30: Fitness = 0.8222
#
# Best fitness in generation 4: 0.8514
# Creating new population...
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Feature subset evaluated: accuracy = 0.8514
# Feature subset evaluated: accuracy = 0.8497
# Feature subset evaluated: accuracy = 0.8490
# Feature subset evaluated: accuracy = 0.8473
# Feature subset evaluated: accuracy = 0.8461
# Feature subset evaluated: accuracy = 0.8429
# Feature subset evaluated: accuracy = 0.8424
# Feature subset evaluated: accuracy = 0.8407
# Feature subset evaluated: accuracy = 0.8400
# Feature subset evaluated: accuracy = 0.8399
# Feature subset evaluated: accuracy = 0.8393
# Feature subset evaluated: accuracy = 0.8392
# Feature subset evaluated: accuracy = 0.8389
# Feature subset evaluated: accuracy = 0.8389
# Feature subset evaluated: accuracy = 0.8377
# Feature subset evaluated: accuracy = 0.8392
# Feature subset evaluated: accuracy = 0.8378
# Feature subset evaluated: accuracy = 0.8539
# Feature subset evaluated: accuracy = 0.8347
# Feature subset evaluated: accuracy = 0.8575
# Feature subset evaluated: accuracy = 0.8387
# Feature subset evaluated: accuracy = 0.8444
# Feature subset evaluated: accuracy = 0.8459
# Feature subset evaluated: accuracy = 0.8441
# Feature subset evaluated: accuracy = 0.8492
# Feature subset evaluated: accuracy = 0.8390
# Feature subset evaluated: accuracy = 0.8128
# Feature subset evaluated: accuracy = 0.8407
# Feature subset evaluated: accuracy = 0.8225
# Feature subset evaluated: accuracy = 0.8410
# Current best: [2, 16, 54, 62, 63, 84, 89, 115, 123, 133, 137, 139, 151, 159, 168, 174, 180, 192, 193, 198, 199, 204, 243, 274, 331, 355, 403, 414, 416, 420]
#
# Generation 5/20
# Evaluating fitness for each individual:
# Feature subset evaluated: accuracy = 0.8514
# Individual 1/30: Fitness = 0.8514
# Feature subset evaluated: accuracy = 0.8497
# Individual 2/30: Fitness = 0.8497
# Feature subset evaluated: accuracy = 0.8490
# Individual 3/30: Fitness = 0.8490
# Feature subset evaluated: accuracy = 0.8473
# Individual 4/30: Fitness = 0.8473
# Feature subset evaluated: accuracy = 0.8461
# Individual 5/30: Fitness = 0.8461
# Feature subset evaluated: accuracy = 0.8429
# Individual 6/30: Fitness = 0.8429
# Feature subset evaluated: accuracy = 0.8424
# Individual 7/30: Fitness = 0.8424
# Feature subset evaluated: accuracy = 0.8407
# Individual 8/30: Fitness = 0.8407
# Feature subset evaluated: accuracy = 0.8400
# Individual 9/30: Fitness = 0.8400
# Feature subset evaluated: accuracy = 0.8399
# Individual 10/30: Fitness = 0.8399
# Feature subset evaluated: accuracy = 0.8393
# Individual 11/30: Fitness = 0.8393
# Feature subset evaluated: accuracy = 0.8392
# Individual 12/30: Fitness = 0.8392
# Feature subset evaluated: accuracy = 0.8389
# Individual 13/30: Fitness = 0.8389
# Feature subset evaluated: accuracy = 0.8389
# Individual 14/30: Fitness = 0.8389
# Feature subset evaluated: accuracy = 0.8377
# Individual 15/30: Fitness = 0.8377
# Feature subset evaluated: accuracy = 0.8392
# Individual 16/30: Fitness = 0.8392
# Feature subset evaluated: accuracy = 0.8378
# Individual 17/30: Fitness = 0.8378
# Feature subset evaluated: accuracy = 0.8539
# Individual 18/30: Fitness = 0.8539
# Feature subset evaluated: accuracy = 0.8347
# Individual 19/30: Fitness = 0.8347
# Feature subset evaluated: accuracy = 0.8575
# Individual 20/30: Fitness = 0.8575
# Feature subset evaluated: accuracy = 0.8387
# Individual 21/30: Fitness = 0.8387
# Feature subset evaluated: accuracy = 0.8444
# Individual 22/30: Fitness = 0.8444
# Feature subset evaluated: accuracy = 0.8459
# Individual 23/30: Fitness = 0.8459
# Feature subset evaluated: accuracy = 0.8441
# Individual 24/30: Fitness = 0.8441
# Feature subset evaluated: accuracy = 0.8492
# Individual 25/30: Fitness = 0.8492
# Feature subset evaluated: accuracy = 0.8390
# Individual 26/30: Fitness = 0.8390
# Feature subset evaluated: accuracy = 0.8128
# Individual 27/30: Fitness = 0.8128
# Feature subset evaluated: accuracy = 0.8407
# Individual 28/30: Fitness = 0.8407
# Feature subset evaluated: accuracy = 0.8225
# Individual 29/30: Fitness = 0.8225
# Feature subset evaluated: accuracy = 0.8410
# Individual 30/30: Fitness = 0.8410
#
# Best fitness in generation 5: 0.8575
# Creating new population...
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Feature subset evaluated: accuracy = 0.8575
# Feature subset evaluated: accuracy = 0.8539
# Feature subset evaluated: accuracy = 0.8514
# Feature subset evaluated: accuracy = 0.8497
# Feature subset evaluated: accuracy = 0.8492
# Feature subset evaluated: accuracy = 0.8490
# Feature subset evaluated: accuracy = 0.8473
# Feature subset evaluated: accuracy = 0.8461
# Feature subset evaluated: accuracy = 0.8459
# Feature subset evaluated: accuracy = 0.8444
# Feature subset evaluated: accuracy = 0.8441
# Feature subset evaluated: accuracy = 0.8429
# Feature subset evaluated: accuracy = 0.8424
# Feature subset evaluated: accuracy = 0.8410
# Feature subset evaluated: accuracy = 0.8407
# Feature subset evaluated: accuracy = 0.8478
# Feature subset evaluated: accuracy = 0.8319
# Feature subset evaluated: accuracy = 0.8205
# Feature subset evaluated: accuracy = 0.8474
# Feature subset evaluated: accuracy = 0.8464
# Feature subset evaluated: accuracy = 0.8389
# Feature subset evaluated: accuracy = 0.8512
# Feature subset evaluated: accuracy = 0.7920
# Feature subset evaluated: accuracy = 0.8637
# Feature subset evaluated: accuracy = 0.8191
# Feature subset evaluated: accuracy = 0.8322
# Feature subset evaluated: accuracy = 0.8447
# Feature subset evaluated: accuracy = 0.8354
# Feature subset evaluated: accuracy = 0.8385
# Feature subset evaluated: accuracy = 0.8444
# Current best: [5, 11, 18, 19, 27, 49, 73, 78, 80, 82, 103, 140, 150, 174, 181, 182, 191, 192, 261, 267, 270, 272, 282, 305, 335, 356, 358, 374, 409, 413]
#
# Generation 6/20
# Evaluating fitness for each individual:
# Feature subset evaluated: accuracy = 0.8575
# Individual 1/30: Fitness = 0.8575
# Feature subset evaluated: accuracy = 0.8539
# Individual 2/30: Fitness = 0.8539
# Feature subset evaluated: accuracy = 0.8514
# Individual 3/30: Fitness = 0.8514
# Feature subset evaluated: accuracy = 0.8497
# Individual 4/30: Fitness = 0.8497
# Feature subset evaluated: accuracy = 0.8492
# Individual 5/30: Fitness = 0.8492
# Feature subset evaluated: accuracy = 0.8490
# Individual 6/30: Fitness = 0.8490
# Feature subset evaluated: accuracy = 0.8473
# Individual 7/30: Fitness = 0.8473
# Feature subset evaluated: accuracy = 0.8461
# Individual 8/30: Fitness = 0.8461
# Feature subset evaluated: accuracy = 0.8459
# Individual 9/30: Fitness = 0.8459
# Feature subset evaluated: accuracy = 0.8444
# Individual 10/30: Fitness = 0.8444
# Feature subset evaluated: accuracy = 0.8441
# Individual 11/30: Fitness = 0.8441
# Feature subset evaluated: accuracy = 0.8429
# Individual 12/30: Fitness = 0.8429
# Feature subset evaluated: accuracy = 0.8424
# Individual 13/30: Fitness = 0.8424
# Feature subset evaluated: accuracy = 0.8410
# Individual 14/30: Fitness = 0.8410
# Feature subset evaluated: accuracy = 0.8407
# Individual 15/30: Fitness = 0.8407
# Feature subset evaluated: accuracy = 0.8478
# Individual 16/30: Fitness = 0.8478
# Feature subset evaluated: accuracy = 0.8319
# Individual 17/30: Fitness = 0.8319
# Feature subset evaluated: accuracy = 0.8205
# Individual 18/30: Fitness = 0.8205
# Feature subset evaluated: accuracy = 0.8474
# Individual 19/30: Fitness = 0.8474
# Feature subset evaluated: accuracy = 0.8464
# Individual 20/30: Fitness = 0.8464
# Feature subset evaluated: accuracy = 0.8389
# Individual 21/30: Fitness = 0.8389
# Feature subset evaluated: accuracy = 0.8512
# Individual 22/30: Fitness = 0.8512
# Feature subset evaluated: accuracy = 0.7920
# Individual 23/30: Fitness = 0.7920
# Feature subset evaluated: accuracy = 0.8637
# Individual 24/30: Fitness = 0.8637
# Feature subset evaluated: accuracy = 0.8191
# Individual 25/30: Fitness = 0.8191
# Feature subset evaluated: accuracy = 0.8322
# Individual 26/30: Fitness = 0.8322
# Feature subset evaluated: accuracy = 0.8447
# Individual 27/30: Fitness = 0.8447
# Feature subset evaluated: accuracy = 0.8354
# Individual 28/30: Fitness = 0.8354
# Feature subset evaluated: accuracy = 0.8385
# Individual 29/30: Fitness = 0.8385
# Feature subset evaluated: accuracy = 0.8444
# Individual 30/30: Fitness = 0.8444
#
# Best fitness in generation 6: 0.8637
# Creating new population...
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Feature subset evaluated: accuracy = 0.8637
# Feature subset evaluated: accuracy = 0.8575
# Feature subset evaluated: accuracy = 0.8539
# Feature subset evaluated: accuracy = 0.8514
# Feature subset evaluated: accuracy = 0.8512
# Feature subset evaluated: accuracy = 0.8497
# Feature subset evaluated: accuracy = 0.8492
# Feature subset evaluated: accuracy = 0.8490
# Feature subset evaluated: accuracy = 0.8478
# Feature subset evaluated: accuracy = 0.8474
# Feature subset evaluated: accuracy = 0.8473
# Feature subset evaluated: accuracy = 0.8464
# Feature subset evaluated: accuracy = 0.8461
# Feature subset evaluated: accuracy = 0.8459
# Feature subset evaluated: accuracy = 0.8447
# Feature subset evaluated: accuracy = 0.8412
# Feature subset evaluated: accuracy = 0.8412
# Feature subset evaluated: accuracy = 0.8340
# Feature subset evaluated: accuracy = 0.8185
# Feature subset evaluated: accuracy = 0.8353
# Feature subset evaluated: accuracy = 0.8311
# Feature subset evaluated: accuracy = 0.8454
# Feature subset evaluated: accuracy = 0.8434
# Feature subset evaluated: accuracy = 0.8354
# Feature subset evaluated: accuracy = 0.8518
# Feature subset evaluated: accuracy = 0.8351
# Feature subset evaluated: accuracy = 0.8461
# Feature subset evaluated: accuracy = 0.8459
# Feature subset evaluated: accuracy = 0.8417
# Feature subset evaluated: accuracy = 0.8419
# Current best: [5, 11, 18, 19, 27, 49, 73, 78, 80, 82, 103, 140, 150, 174, 181, 182, 191, 192, 261, 267, 270, 272, 282, 305, 335, 356, 358, 374, 409, 413]
#
# Generation 7/20
# Evaluating fitness for each individual:
# Feature subset evaluated: accuracy = 0.8637
# Individual 1/30: Fitness = 0.8637
# Feature subset evaluated: accuracy = 0.8575
# Individual 2/30: Fitness = 0.8575
# Feature subset evaluated: accuracy = 0.8539
# Individual 3/30: Fitness = 0.8539
# Feature subset evaluated: accuracy = 0.8514
# Individual 4/30: Fitness = 0.8514
# Feature subset evaluated: accuracy = 0.8512
# Individual 5/30: Fitness = 0.8512
# Feature subset evaluated: accuracy = 0.8497
# Individual 6/30: Fitness = 0.8497
# Feature subset evaluated: accuracy = 0.8492
# Individual 7/30: Fitness = 0.8492
# Feature subset evaluated: accuracy = 0.8490
# Individual 8/30: Fitness = 0.8490
# Feature subset evaluated: accuracy = 0.8478
# Individual 9/30: Fitness = 0.8478
# Feature subset evaluated: accuracy = 0.8474
# Individual 10/30: Fitness = 0.8474
# Feature subset evaluated: accuracy = 0.8473
# Individual 11/30: Fitness = 0.8473
# Feature subset evaluated: accuracy = 0.8464
# Individual 12/30: Fitness = 0.8464
# Feature subset evaluated: accuracy = 0.8461
# Individual 13/30: Fitness = 0.8461
# Feature subset evaluated: accuracy = 0.8459
# Individual 14/30: Fitness = 0.8459
# Feature subset evaluated: accuracy = 0.8447
# Individual 15/30: Fitness = 0.8447
# Feature subset evaluated: accuracy = 0.8412
# Individual 16/30: Fitness = 0.8412
# Feature subset evaluated: accuracy = 0.8412
# Individual 17/30: Fitness = 0.8412
# Feature subset evaluated: accuracy = 0.8340
# Individual 18/30: Fitness = 0.8340
# Feature subset evaluated: accuracy = 0.8185
# Individual 19/30: Fitness = 0.8185
# Feature subset evaluated: accuracy = 0.8353
# Individual 20/30: Fitness = 0.8353
# Feature subset evaluated: accuracy = 0.8311
# Individual 21/30: Fitness = 0.8311
# Feature subset evaluated: accuracy = 0.8454
# Individual 22/30: Fitness = 0.8454
# Feature subset evaluated: accuracy = 0.8434
# Individual 23/30: Fitness = 0.8434
# Feature subset evaluated: accuracy = 0.8354
# Individual 24/30: Fitness = 0.8354
# Feature subset evaluated: accuracy = 0.8518
# Individual 25/30: Fitness = 0.8518
# Feature subset evaluated: accuracy = 0.8351
# Individual 26/30: Fitness = 0.8351
# Feature subset evaluated: accuracy = 0.8461
# Individual 27/30: Fitness = 0.8461
# Feature subset evaluated: accuracy = 0.8459
# Individual 28/30: Fitness = 0.8459
# Feature subset evaluated: accuracy = 0.8417
# Individual 29/30: Fitness = 0.8417
# Feature subset evaluated: accuracy = 0.8419
# Individual 30/30: Fitness = 0.8419
#
# Best fitness in generation 7: 0.8637
# Creating new population...
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Feature subset evaluated: accuracy = 0.8637
# Feature subset evaluated: accuracy = 0.8575
# Feature subset evaluated: accuracy = 0.8539
# Feature subset evaluated: accuracy = 0.8518
# Feature subset evaluated: accuracy = 0.8514
# Feature subset evaluated: accuracy = 0.8512
# Feature subset evaluated: accuracy = 0.8497
# Feature subset evaluated: accuracy = 0.8492
# Feature subset evaluated: accuracy = 0.8490
# Feature subset evaluated: accuracy = 0.8478
# Feature subset evaluated: accuracy = 0.8474
# Feature subset evaluated: accuracy = 0.8473
# Feature subset evaluated: accuracy = 0.8464
# Feature subset evaluated: accuracy = 0.8461
# Feature subset evaluated: accuracy = 0.8461
# Feature subset evaluated: accuracy = 0.8287
# Feature subset evaluated: accuracy = 0.8613
# Feature subset evaluated: accuracy = 0.8482
# Feature subset evaluated: accuracy = 0.8553
# Feature subset evaluated: accuracy = 0.8417
# Feature subset evaluated: accuracy = 0.8470
# Feature subset evaluated: accuracy = 0.8485
# Feature subset evaluated: accuracy = 0.8417
# Feature subset evaluated: accuracy = 0.8798
# Feature subset evaluated: accuracy = 0.8408
# Feature subset evaluated: accuracy = 0.8443
# Feature subset evaluated: accuracy = 0.8128
# Feature subset evaluated: accuracy = 0.8599
# Feature subset evaluated: accuracy = 0.8156
# Feature subset evaluated: accuracy = 0.8492
# Current best: [13, 16, 18, 19, 27, 49, 73, 80, 83, 99, 103, 115, 118, 150, 174, 179, 181, 191, 208, 270, 272, 297, 315, 318, 327, 330, 335, 358, 413, 432]
#
# Generation 8/20
# Evaluating fitness for each individual:
# Feature subset evaluated: accuracy = 0.8637
# Individual 1/30: Fitness = 0.8637
# Feature subset evaluated: accuracy = 0.8575
# Individual 2/30: Fitness = 0.8575
# Feature subset evaluated: accuracy = 0.8539
# Individual 3/30: Fitness = 0.8539
# Feature subset evaluated: accuracy = 0.8518
# Individual 4/30: Fitness = 0.8518
# Feature subset evaluated: accuracy = 0.8514
# Individual 5/30: Fitness = 0.8514
# Feature subset evaluated: accuracy = 0.8512
# Individual 6/30: Fitness = 0.8512
# Feature subset evaluated: accuracy = 0.8497
# Individual 7/30: Fitness = 0.8497
# Feature subset evaluated: accuracy = 0.8492
# Individual 8/30: Fitness = 0.8492
# Feature subset evaluated: accuracy = 0.8490
# Individual 9/30: Fitness = 0.8490
# Feature subset evaluated: accuracy = 0.8478
# Individual 10/30: Fitness = 0.8478
# Feature subset evaluated: accuracy = 0.8474
# Individual 11/30: Fitness = 0.8474
# Feature subset evaluated: accuracy = 0.8473
# Individual 12/30: Fitness = 0.8473
# Feature subset evaluated: accuracy = 0.8464
# Individual 13/30: Fitness = 0.8464
# Feature subset evaluated: accuracy = 0.8461
# Individual 14/30: Fitness = 0.8461
# Feature subset evaluated: accuracy = 0.8461
# Individual 15/30: Fitness = 0.8461
# Feature subset evaluated: accuracy = 0.8287
# Individual 16/30: Fitness = 0.8287
# Feature subset evaluated: accuracy = 0.8613
# Individual 17/30: Fitness = 0.8613
# Feature subset evaluated: accuracy = 0.8482
# Individual 18/30: Fitness = 0.8482
# Feature subset evaluated: accuracy = 0.8553
# Individual 19/30: Fitness = 0.8553
# Feature subset evaluated: accuracy = 0.8417
# Individual 20/30: Fitness = 0.8417
# Feature subset evaluated: accuracy = 0.8470
# Individual 21/30: Fitness = 0.8470
# Feature subset evaluated: accuracy = 0.8485
# Individual 22/30: Fitness = 0.8485
# Feature subset evaluated: accuracy = 0.8417
# Individual 23/30: Fitness = 0.8417
# Feature subset evaluated: accuracy = 0.8798
# Individual 24/30: Fitness = 0.8798
# Feature subset evaluated: accuracy = 0.8408
# Individual 25/30: Fitness = 0.8408
# Feature subset evaluated: accuracy = 0.8443
# Individual 26/30: Fitness = 0.8443
# Feature subset evaluated: accuracy = 0.8128
# Individual 27/30: Fitness = 0.8128
# Feature subset evaluated: accuracy = 0.8599
# Individual 28/30: Fitness = 0.8599
# Feature subset evaluated: accuracy = 0.8156
# Individual 29/30: Fitness = 0.8156
# Feature subset evaluated: accuracy = 0.8492
# Individual 30/30: Fitness = 0.8492
#
# Best fitness in generation 8: 0.8798
# Creating new population...
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Feature subset evaluated: accuracy = 0.8798
# Feature subset evaluated: accuracy = 0.8637
# Feature subset evaluated: accuracy = 0.8613
# Feature subset evaluated: accuracy = 0.8599
# Feature subset evaluated: accuracy = 0.8575
# Feature subset evaluated: accuracy = 0.8553
# Feature subset evaluated: accuracy = 0.8539
# Feature subset evaluated: accuracy = 0.8518
# Feature subset evaluated: accuracy = 0.8514
# Feature subset evaluated: accuracy = 0.8512
# Feature subset evaluated: accuracy = 0.8497
# Feature subset evaluated: accuracy = 0.8492
# Feature subset evaluated: accuracy = 0.8492
# Feature subset evaluated: accuracy = 0.8490
# Feature subset evaluated: accuracy = 0.8485
# Feature subset evaluated: accuracy = 0.8628
# Feature subset evaluated: accuracy = 0.8348
# Feature subset evaluated: accuracy = 0.8398
# Feature subset evaluated: accuracy = 0.8602
# Feature subset evaluated: accuracy = 0.8479
# Feature subset evaluated: accuracy = 0.8196
# Feature subset evaluated: accuracy = 0.8630
# Feature subset evaluated: accuracy = 0.8460
# Feature subset evaluated: accuracy = 0.8422
# Feature subset evaluated: accuracy = 0.8477
# Feature subset evaluated: accuracy = 0.8526
# Feature subset evaluated: accuracy = 0.8505
# Feature subset evaluated: accuracy = 0.8555
# Feature subset evaluated: accuracy = 0.8167
# Feature subset evaluated: accuracy = 0.8699
# Current best: [13, 16, 18, 19, 27, 49, 73, 80, 83, 99, 103, 115, 118, 150, 174, 179, 181, 191, 208, 270, 272, 297, 315, 318, 327, 330, 335, 358, 413, 432]
#
# Generation 9/20
# Evaluating fitness for each individual:
# Feature subset evaluated: accuracy = 0.8798
# Individual 1/30: Fitness = 0.8798
# Feature subset evaluated: accuracy = 0.8637
# Individual 2/30: Fitness = 0.8637
# Feature subset evaluated: accuracy = 0.8613
# Individual 3/30: Fitness = 0.8613
# Feature subset evaluated: accuracy = 0.8599
# Individual 4/30: Fitness = 0.8599
# Feature subset evaluated: accuracy = 0.8575
# Individual 5/30: Fitness = 0.8575
# Feature subset evaluated: accuracy = 0.8553
# Individual 6/30: Fitness = 0.8553
# Feature subset evaluated: accuracy = 0.8539
# Individual 7/30: Fitness = 0.8539
# Feature subset evaluated: accuracy = 0.8518
# Individual 8/30: Fitness = 0.8518
# Feature subset evaluated: accuracy = 0.8514
# Individual 9/30: Fitness = 0.8514
# Feature subset evaluated: accuracy = 0.8512
# Individual 10/30: Fitness = 0.8512
# Feature subset evaluated: accuracy = 0.8497
# Individual 11/30: Fitness = 0.8497
# Feature subset evaluated: accuracy = 0.8492
# Individual 12/30: Fitness = 0.8492
# Feature subset evaluated: accuracy = 0.8492
# Individual 13/30: Fitness = 0.8492
# Feature subset evaluated: accuracy = 0.8490
# Individual 14/30: Fitness = 0.8490
# Feature subset evaluated: accuracy = 0.8485
# Individual 15/30: Fitness = 0.8485
# Feature subset evaluated: accuracy = 0.8628
# Individual 16/30: Fitness = 0.8628
# Feature subset evaluated: accuracy = 0.8348
# Individual 17/30: Fitness = 0.8348
# Feature subset evaluated: accuracy = 0.8398
# Individual 18/30: Fitness = 0.8398
# Feature subset evaluated: accuracy = 0.8602
# Individual 19/30: Fitness = 0.8602
# Feature subset evaluated: accuracy = 0.8479
# Individual 20/30: Fitness = 0.8479
# Feature subset evaluated: accuracy = 0.8196
# Individual 21/30: Fitness = 0.8196
# Feature subset evaluated: accuracy = 0.8630
# Individual 22/30: Fitness = 0.8630
# Feature subset evaluated: accuracy = 0.8460
# Individual 23/30: Fitness = 0.8460
# Feature subset evaluated: accuracy = 0.8422
# Individual 24/30: Fitness = 0.8422
# Feature subset evaluated: accuracy = 0.8477
# Individual 25/30: Fitness = 0.8477
# Feature subset evaluated: accuracy = 0.8526
# Individual 26/30: Fitness = 0.8526
# Feature subset evaluated: accuracy = 0.8505
# Individual 27/30: Fitness = 0.8505
# Feature subset evaluated: accuracy = 0.8555
# Individual 28/30: Fitness = 0.8555
# Feature subset evaluated: accuracy = 0.8167
# Individual 29/30: Fitness = 0.8167
# Feature subset evaluated: accuracy = 0.8699
# Individual 30/30: Fitness = 0.8699
#
# Best fitness in generation 9: 0.8798
# Creating new population...
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Feature subset evaluated: accuracy = 0.8798
# Feature subset evaluated: accuracy = 0.8699
# Feature subset evaluated: accuracy = 0.8637
# Feature subset evaluated: accuracy = 0.8630
# Feature subset evaluated: accuracy = 0.8628
# Feature subset evaluated: accuracy = 0.8613
# Feature subset evaluated: accuracy = 0.8602
# Feature subset evaluated: accuracy = 0.8599
# Feature subset evaluated: accuracy = 0.8575
# Feature subset evaluated: accuracy = 0.8555
# Feature subset evaluated: accuracy = 0.8553
# Feature subset evaluated: accuracy = 0.8539
# Feature subset evaluated: accuracy = 0.8526
# Feature subset evaluated: accuracy = 0.8518
# Feature subset evaluated: accuracy = 0.8514
# Feature subset evaluated: accuracy = 0.8500
# Feature subset evaluated: accuracy = 0.8555
# Feature subset evaluated: accuracy = 0.8369
# Feature subset evaluated: accuracy = 0.8583
# Feature subset evaluated: accuracy = 0.8574
# Feature subset evaluated: accuracy = 0.8519
# Feature subset evaluated: accuracy = 0.8548
# Feature subset evaluated: accuracy = 0.8401
# Feature subset evaluated: accuracy = 0.8481
# Feature subset evaluated: accuracy = 0.8478
# Feature subset evaluated: accuracy = 0.8628
# Feature subset evaluated: accuracy = 0.8499
# Feature subset evaluated: accuracy = 0.8448
# Feature subset evaluated: accuracy = 0.8195
# Feature subset evaluated: accuracy = 0.8494
# Current best: [13, 16, 18, 19, 27, 49, 73, 80, 83, 99, 103, 115, 118, 150, 174, 179, 181, 191, 208, 270, 272, 297, 315, 318, 327, 330, 335, 358, 413, 432]
#
# Generation 10/20
# Evaluating fitness for each individual:
# Feature subset evaluated: accuracy = 0.8798
# Individual 1/30: Fitness = 0.8798
# Feature subset evaluated: accuracy = 0.8699
# Individual 2/30: Fitness = 0.8699
# Feature subset evaluated: accuracy = 0.8637
# Individual 3/30: Fitness = 0.8637
# Feature subset evaluated: accuracy = 0.8630
# Individual 4/30: Fitness = 0.8630
# Feature subset evaluated: accuracy = 0.8628
# Individual 5/30: Fitness = 0.8628
# Feature subset evaluated: accuracy = 0.8613
# Individual 6/30: Fitness = 0.8613
# Feature subset evaluated: accuracy = 0.8602
# Individual 7/30: Fitness = 0.8602
# Feature subset evaluated: accuracy = 0.8599
# Individual 8/30: Fitness = 0.8599
# Feature subset evaluated: accuracy = 0.8575
# Individual 9/30: Fitness = 0.8575
# Feature subset evaluated: accuracy = 0.8555
# Individual 10/30: Fitness = 0.8555
# Feature subset evaluated: accuracy = 0.8553
# Individual 11/30: Fitness = 0.8553
# Feature subset evaluated: accuracy = 0.8539
# Individual 12/30: Fitness = 0.8539
# Feature subset evaluated: accuracy = 0.8526
# Individual 13/30: Fitness = 0.8526
# Feature subset evaluated: accuracy = 0.8518
# Individual 14/30: Fitness = 0.8518
# Feature subset evaluated: accuracy = 0.8514
# Individual 15/30: Fitness = 0.8514
# Feature subset evaluated: accuracy = 0.8500
# Individual 16/30: Fitness = 0.8500
# Feature subset evaluated: accuracy = 0.8555
# Individual 17/30: Fitness = 0.8555
# Feature subset evaluated: accuracy = 0.8369
# Individual 18/30: Fitness = 0.8369
# Feature subset evaluated: accuracy = 0.8583
# Individual 19/30: Fitness = 0.8583
# Feature subset evaluated: accuracy = 0.8574
# Individual 20/30: Fitness = 0.8574
# Feature subset evaluated: accuracy = 0.8519
# Individual 21/30: Fitness = 0.8519
# Feature subset evaluated: accuracy = 0.8548
# Individual 22/30: Fitness = 0.8548
# Feature subset evaluated: accuracy = 0.8401
# Individual 23/30: Fitness = 0.8401
# Feature subset evaluated: accuracy = 0.8481
# Individual 24/30: Fitness = 0.8481
# Feature subset evaluated: accuracy = 0.8478
# Individual 25/30: Fitness = 0.8478
# Feature subset evaluated: accuracy = 0.8628
# Individual 26/30: Fitness = 0.8628
# Feature subset evaluated: accuracy = 0.8499
# Individual 27/30: Fitness = 0.8499
# Feature subset evaluated: accuracy = 0.8448
# Individual 28/30: Fitness = 0.8448
# Feature subset evaluated: accuracy = 0.8195
# Individual 29/30: Fitness = 0.8195
# Feature subset evaluated: accuracy = 0.8494
# Individual 30/30: Fitness = 0.8494
#
# Best fitness in generation 10: 0.8798
# Creating new population...
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# ...
# Feature subset evaluated: accuracy = 0.8849
# Individual 9/30: Fitness = 0.8849
# Feature subset evaluated: accuracy = 0.8849
# Individual 10/30: Fitness = 0.8849
# Feature subset evaluated: accuracy = 0.8844
# Individual 11/30: Fitness = 0.8844
# Feature subset evaluated: accuracy = 0.8817
# Individual 12/30: Fitness = 0.8817
# Feature subset evaluated: accuracy = 0.8808
# Individual 13/30: Fitness = 0.8808
# Feature subset evaluated: accuracy = 0.8807
# Individual 14/30: Fitness = 0.8807
# Feature subset evaluated: accuracy = 0.8804
# Individual 15/30: Fitness = 0.8804
# Feature subset evaluated: accuracy = 0.8611
# Individual 16/30: Fitness = 0.8611
# Feature subset evaluated: accuracy = 0.8999
# Individual 17/30: Fitness = 0.8999
# Feature subset evaluated: accuracy = 0.8806
# Individual 18/30: Fitness = 0.8806
# Feature subset evaluated: accuracy = 0.8898
# Individual 19/30: Fitness = 0.8898
# Feature subset evaluated: accuracy = 0.8758
# Individual 20/30: Fitness = 0.8758
# Feature subset evaluated: accuracy = 0.8735
# Individual 21/30: Fitness = 0.8735
# Feature subset evaluated: accuracy = 0.8813
# Individual 22/30: Fitness = 0.8813
# Feature subset evaluated: accuracy = 0.8773
# Individual 23/30: Fitness = 0.8773
# Feature subset evaluated: accuracy = 0.8740
# Individual 24/30: Fitness = 0.8740
# Feature subset evaluated: accuracy = 0.8853
# Individual 25/30: Fitness = 0.8853
# Feature subset evaluated: accuracy = 0.8758
# Individual 26/30: Fitness = 0.8758
# Feature subset evaluated: accuracy = 0.8775
# Individual 27/30: Fitness = 0.8775
# Feature subset evaluated: accuracy = 0.8821
# Individual 28/30: Fitness = 0.8821
# Feature subset evaluated: accuracy = 0.8711
# Individual 29/30: Fitness = 0.8711
# Feature subset evaluated: accuracy = 0.8688
# Individual 30/30: Fitness = 0.8688
#
# Best fitness in generation 18: 0.8999
# Creating new population...
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Feature subset evaluated: accuracy = 0.8999
# Feature subset evaluated: accuracy = 0.8950
# Feature subset evaluated: accuracy = 0.8930
# Feature subset evaluated: accuracy = 0.8904
# Feature subset evaluated: accuracy = 0.8898
# Feature subset evaluated: accuracy = 0.8872
# Feature subset evaluated: accuracy = 0.8869
# Feature subset evaluated: accuracy = 0.8865
# Feature subset evaluated: accuracy = 0.8862
# Feature subset evaluated: accuracy = 0.8861
# Feature subset evaluated: accuracy = 0.8853
# Feature subset evaluated: accuracy = 0.8849
# Feature subset evaluated: accuracy = 0.8849
# Feature subset evaluated: accuracy = 0.8844
# Feature subset evaluated: accuracy = 0.8821
# Feature subset evaluated: accuracy = 0.8868
# Feature subset evaluated: accuracy = 0.8769
# Feature subset evaluated: accuracy = 0.8755
# Feature subset evaluated: accuracy = 0.8794
# Feature subset evaluated: accuracy = 0.8541
# Feature subset evaluated: accuracy = 0.8725
# Feature subset evaluated: accuracy = 0.8864
# Feature subset evaluated: accuracy = 0.8727
# Feature subset evaluated: accuracy = 0.8851
# Feature subset evaluated: accuracy = 0.8835
# Feature subset evaluated: accuracy = 0.8955
# Feature subset evaluated: accuracy = 0.8818
# Feature subset evaluated: accuracy = 0.8820
# Feature subset evaluated: accuracy = 0.8890
# Feature subset evaluated: accuracy = 0.9019
# Current best: [2, 11, 44, 54, 80, 83, 115, 123, 133, 139, 150, 151, 155, 159, 168, 179, 181, 182, 243, 261, 272, 282, 297, 327, 330, 335, 358, 399, 409, 416]
#
# Generation 19/20
# Evaluating fitness for each individual:
# Feature subset evaluated: accuracy = 0.8999
# Individual 1/30: Fitness = 0.8999
# Feature subset evaluated: accuracy = 0.8950
# Individual 2/30: Fitness = 0.8950
# Feature subset evaluated: accuracy = 0.8930
# Individual 3/30: Fitness = 0.8930
# Feature subset evaluated: accuracy = 0.8904
# Individual 4/30: Fitness = 0.8904
# Feature subset evaluated: accuracy = 0.8898
# Individual 5/30: Fitness = 0.8898
# Feature subset evaluated: accuracy = 0.8872
# Individual 6/30: Fitness = 0.8872
# Feature subset evaluated: accuracy = 0.8869
# Individual 7/30: Fitness = 0.8869
# Feature subset evaluated: accuracy = 0.8865
# Individual 8/30: Fitness = 0.8865
# Feature subset evaluated: accuracy = 0.8862
# Individual 9/30: Fitness = 0.8862
# Feature subset evaluated: accuracy = 0.8861
# Individual 10/30: Fitness = 0.8861
# Feature subset evaluated: accuracy = 0.8853
# Individual 11/30: Fitness = 0.8853
# Feature subset evaluated: accuracy = 0.8849
# Individual 12/30: Fitness = 0.8849
# Feature subset evaluated: accuracy = 0.8849
# Individual 13/30: Fitness = 0.8849
# Feature subset evaluated: accuracy = 0.8844
# Individual 14/30: Fitness = 0.8844
# Feature subset evaluated: accuracy = 0.8821
# Individual 15/30: Fitness = 0.8821
# Feature subset evaluated: accuracy = 0.8868
# Individual 16/30: Fitness = 0.8868
# Feature subset evaluated: accuracy = 0.8769
# Individual 17/30: Fitness = 0.8769
# Feature subset evaluated: accuracy = 0.8755
# Individual 18/30: Fitness = 0.8755
# Feature subset evaluated: accuracy = 0.8794
# Individual 19/30: Fitness = 0.8794
# Feature subset evaluated: accuracy = 0.8541
# Individual 20/30: Fitness = 0.8541
# Feature subset evaluated: accuracy = 0.8725
# Individual 21/30: Fitness = 0.8725
# Feature subset evaluated: accuracy = 0.8864
# Individual 22/30: Fitness = 0.8864
# Feature subset evaluated: accuracy = 0.8727
# Individual 23/30: Fitness = 0.8727
# Feature subset evaluated: accuracy = 0.8851
# Individual 24/30: Fitness = 0.8851
# Feature subset evaluated: accuracy = 0.8835
# Individual 25/30: Fitness = 0.8835
# Feature subset evaluated: accuracy = 0.8955
# Individual 26/30: Fitness = 0.8955
# Feature subset evaluated: accuracy = 0.8818
# Individual 27/30: Fitness = 0.8818
# Feature subset evaluated: accuracy = 0.8820
# Individual 28/30: Fitness = 0.8820
# Feature subset evaluated: accuracy = 0.8890
# Individual 29/30: Fitness = 0.8890
# Feature subset evaluated: accuracy = 0.9019
# Individual 30/30: Fitness = 0.9019
#
# Best fitness in generation 19: 0.9019
# Creating new population...
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Feature subset evaluated: accuracy = 0.9019
# Feature subset evaluated: accuracy = 0.8999
# Feature subset evaluated: accuracy = 0.8955
# Feature subset evaluated: accuracy = 0.8950
# Feature subset evaluated: accuracy = 0.8930
# Feature subset evaluated: accuracy = 0.8904
# Feature subset evaluated: accuracy = 0.8898
# Feature subset evaluated: accuracy = 0.8890
# Feature subset evaluated: accuracy = 0.8872
# Feature subset evaluated: accuracy = 0.8869
# Feature subset evaluated: accuracy = 0.8868
# Feature subset evaluated: accuracy = 0.8865
# Feature subset evaluated: accuracy = 0.8864
# Feature subset evaluated: accuracy = 0.8862
# Feature subset evaluated: accuracy = 0.8861
# Feature subset evaluated: accuracy = 0.8883
# Feature subset evaluated: accuracy = 0.8700
# Feature subset evaluated: accuracy = 0.8787
# Feature subset evaluated: accuracy = 0.8859
# Feature subset evaluated: accuracy = 0.8798
# Feature subset evaluated: accuracy = 0.8864
# Feature subset evaluated: accuracy = 0.8831
# Feature subset evaluated: accuracy = 0.8833
# Feature subset evaluated: accuracy = 0.8774
# Feature subset evaluated: accuracy = 0.8879
# Feature subset evaluated: accuracy = 0.8866
# Feature subset evaluated: accuracy = 0.8867
# Feature subset evaluated: accuracy = 0.8779
# Feature subset evaluated: accuracy = 0.8861
# Feature subset evaluated: accuracy = 0.8724
# Current best: [2, 11, 44, 54, 80, 83, 115, 123, 133, 139, 150, 151, 155, 159, 168, 179, 181, 182, 243, 261, 272, 282, 297, 327, 330, 335, 358, 399, 409, 416]
#
# Generation 20/20
# Evaluating fitness for each individual:
# Feature subset evaluated: accuracy = 0.9019
# Individual 1/30: Fitness = 0.9019
# Feature subset evaluated: accuracy = 0.8999
# Individual 2/30: Fitness = 0.8999
# Feature subset evaluated: accuracy = 0.8955
# Individual 3/30: Fitness = 0.8955
# Feature subset evaluated: accuracy = 0.8950
# Individual 4/30: Fitness = 0.8950
# Feature subset evaluated: accuracy = 0.8930
# Individual 5/30: Fitness = 0.8930
# Feature subset evaluated: accuracy = 0.8904
# Individual 6/30: Fitness = 0.8904
# Feature subset evaluated: accuracy = 0.8898
# Individual 7/30: Fitness = 0.8898
# Feature subset evaluated: accuracy = 0.8890
# Individual 8/30: Fitness = 0.8890
# Feature subset evaluated: accuracy = 0.8872
# Individual 9/30: Fitness = 0.8872
# Feature subset evaluated: accuracy = 0.8869
# Individual 10/30: Fitness = 0.8869
# Feature subset evaluated: accuracy = 0.8868
# Individual 11/30: Fitness = 0.8868
# Feature subset evaluated: accuracy = 0.8865
# Individual 12/30: Fitness = 0.8865
# Feature subset evaluated: accuracy = 0.8864
# Individual 13/30: Fitness = 0.8864
# Feature subset evaluated: accuracy = 0.8862
# Individual 14/30: Fitness = 0.8862
# Feature subset evaluated: accuracy = 0.8861
# Individual 15/30: Fitness = 0.8861
# Feature subset evaluated: accuracy = 0.8883
# Individual 16/30: Fitness = 0.8883
# Feature subset evaluated: accuracy = 0.8700
# Individual 17/30: Fitness = 0.8700
# Feature subset evaluated: accuracy = 0.8787
# Individual 18/30: Fitness = 0.8787
# Feature subset evaluated: accuracy = 0.8859
# Individual 19/30: Fitness = 0.8859
# Feature subset evaluated: accuracy = 0.8798
# Individual 20/30: Fitness = 0.8798
# Feature subset evaluated: accuracy = 0.8864
# Individual 21/30: Fitness = 0.8864
# Feature subset evaluated: accuracy = 0.8831
# Individual 22/30: Fitness = 0.8831
# Feature subset evaluated: accuracy = 0.8833
# Individual 23/30: Fitness = 0.8833
# Feature subset evaluated: accuracy = 0.8774
# Individual 24/30: Fitness = 0.8774
# Feature subset evaluated: accuracy = 0.8879
# Individual 25/30: Fitness = 0.8879
# Feature subset evaluated: accuracy = 0.8866
# Individual 26/30: Fitness = 0.8866
# Feature subset evaluated: accuracy = 0.8867
# Individual 27/30: Fitness = 0.8867
# Feature subset evaluated: accuracy = 0.8779
# Individual 28/30: Fitness = 0.8779
# Feature subset evaluated: accuracy = 0.8861
# Individual 29/30: Fitness = 0.8861
# Feature subset evaluated: accuracy = 0.8724
# Individual 30/30: Fitness = 0.8724
#
# Best fitness in generation 20: 0.9019
# Creating new population...
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Generating new individual...
# New individual created! Happy birthday!
# Feature subset evaluated: accuracy = 0.9019
# Feature subset evaluated: accuracy = 0.8999
# Feature subset evaluated: accuracy = 0.8955
# Feature subset evaluated: accuracy = 0.8950
# Feature subset evaluated: accuracy = 0.8930
# Feature subset evaluated: accuracy = 0.8904
# Feature subset evaluated: accuracy = 0.8898
# Feature subset evaluated: accuracy = 0.8890
# Feature subset evaluated: accuracy = 0.8883
# Feature subset evaluated: accuracy = 0.8879
# Feature subset evaluated: accuracy = 0.8872
# Feature subset evaluated: accuracy = 0.8869
# Feature subset evaluated: accuracy = 0.8868
# Feature subset evaluated: accuracy = 0.8867
# Feature subset evaluated: accuracy = 0.8866
# Feature subset evaluated: accuracy = 0.8904
# Feature subset evaluated: accuracy = 0.8872
# Feature subset evaluated: accuracy = 0.8821
# Feature subset evaluated: accuracy = 0.8893
# Feature subset evaluated: accuracy = 0.8917
# Feature subset evaluated: accuracy = 0.8854
# Feature subset evaluated: accuracy = 0.8994
# Feature subset evaluated: accuracy = 0.8733
# Feature subset evaluated: accuracy = 0.8850
# Feature subset evaluated: accuracy = 0.8809
# Feature subset evaluated: accuracy = 0.8720
# Feature subset evaluated: accuracy = 0.8900
# Feature subset evaluated: accuracy = 0.8868
# Feature subset evaluated: accuracy = 0.8859
# Feature subset evaluated: accuracy = 0.8892
# Current best: [2, 11, 44, 54, 80, 83, 115, 123, 133, 139, 150, 151, 155, 159, 168, 179, 181, 182, 243, 261, 272, 282, 297, 327, 330, 335, 358, 399, 409, 416]
# Feature subset evaluated: accuracy = 0.9019
# Feature subset evaluated: accuracy = 0.8999
# Feature subset evaluated: accuracy = 0.8955
# Feature subset evaluated: accuracy = 0.8950
# Feature subset evaluated: accuracy = 0.8930
# Feature subset evaluated: accuracy = 0.8904
# Feature subset evaluated: accuracy = 0.8898
# Feature subset evaluated: accuracy = 0.8890
# Feature subset evaluated: accuracy = 0.8883
# Feature subset evaluated: accuracy = 0.8879
# Feature subset evaluated: accuracy = 0.8872
# Feature subset evaluated: accuracy = 0.8869
# Feature subset evaluated: accuracy = 0.8868
# Feature subset evaluated: accuracy = 0.8867
# Feature subset evaluated: accuracy = 0.8866
# Feature subset evaluated: accuracy = 0.8904
# Feature subset evaluated: accuracy = 0.8872
# Feature subset evaluated: accuracy = 0.8821
# Feature subset evaluated: accuracy = 0.8893
# Feature subset evaluated: accuracy = 0.8917
# Feature subset evaluated: accuracy = 0.8854
# Feature subset evaluated: accuracy = 0.8994
# Feature subset evaluated: accuracy = 0.8733
# Feature subset evaluated: accuracy = 0.8850
# Feature subset evaluated: accuracy = 0.8809
# Feature subset evaluated: accuracy = 0.8720
# Feature subset evaluated: accuracy = 0.8900
# Feature subset evaluated: accuracy = 0.8868
# Feature subset evaluated: accuracy = 0.8859
# Feature subset evaluated: accuracy = 0.8892
# 0:	learn: 0.6595755	total: 30.7ms	remaining: 15.3s
# 100:	learn: 0.5137133	total: 3.26s	remaining: 12.9s
# 200:	learn: 0.4982146	total: 6.53s	remaining: 9.71s
# 300:	learn: 0.4877633	total: 9.7s	remaining: 6.41s
# 400:	learn: 0.4802529	total: 13.1s	remaining: 3.22s
# 499:	learn: 0.4742691	total: 16.2s	remaining: 0us
# Model accuracy with selected features: 0.9019033427032885

# %%
X_test_ga = test.iloc[:, best_features]
y_pred_test = model.predict_proba(X_test_ga)
fraud_probs = y_pred_test[:, 1]


submission_df = pd.DataFrame({
    'TransactionID': transaction_ids,
    'isFraud': fraud_probs
})

submission_df.to_csv('submissions/ga.csv', index=False)
